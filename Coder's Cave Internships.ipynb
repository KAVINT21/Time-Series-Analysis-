# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("D:\\Internships\\CodersCave\\long_data_.csv",parse_dates=["Dates"],index_col="Dates")
df
# Out:
#                States Regions   latitude  longitude  Usage
# Dates
# 2019-02-01     Punjab      NR  31.519974  75.980003  119.9
# 2019-02-01    Haryana      NR  28.450006  77.019991  130.3
# 2019-02-01  Rajasthan      NR  26.449999  74.639981  234.1
# 2019-02-01      Delhi      NR  28.669993  77.230004   85.8
# 2019-02-01         UP      NR  27.599981  78.050006  313.9
# ...               ...     ...        ...        ...    ...
# 2020-05-12    Manipur     NER  24.799971  93.950017    2.5
# 2020-05-12  Meghalaya     NER  25.570492  91.880014    5.8
# 2020-05-12    Mizoram     NER  23.710399  92.720015    1.6
# 2020-05-12   Nagaland     NER  25.666998  94.116570    2.1
# 2020-05-12    Tripura     NER  23.835404  91.279999    3.3
#
# [16599 rows x 5 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2019-02-01', '2019-02-01', '2019-02-01', '2019-02-01',
#                '2019-02-01', '2019-02-01', '2019-02-01', '2019-02-01',
#                '2019-02-01', '2019-02-01',
#                ...
#                '2020-05-12', '2020-05-12', '2020-05-12', '2020-05-12',
#                '2020-05-12', '2020-05-12', '2020-05-12', '2020-05-12',
#                '2020-05-12', '2020-05-12'],
#               dtype='datetime64[ns]', name='Dates', length=16599, freq=None)

# %%
df["2019"]
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8720\1806618128.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2019"]
#                States Regions   latitude  longitude  Usage
# Dates
# 2019-02-01     Punjab      NR  31.519974  75.980003  119.9
# 2019-02-01    Haryana      NR  28.450006  77.019991  130.3
# 2019-02-01  Rajasthan      NR  26.449999  74.639981  234.1
# 2019-02-01      Delhi      NR  28.669993  77.230004   85.8
# 2019-02-01         UP      NR  27.599981  78.050006  313.9
# ...               ...     ...        ...        ...    ...
# 2019-12-31    Manipur     NER  24.799971  93.950017    2.5
# 2019-12-31  Meghalaya     NER  25.570492  91.880014    5.7
# 2019-12-31    Mizoram     NER  23.710399  92.720015    1.7
# 2019-12-31   Nagaland     NER  25.666998  94.116570    2.2
# ...

# %%
df["2019-01-1":"2019-01-31"]
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_8720\614656255.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df["2019-01-1":"2019-01-31"]
#                States Regions   latitude  longitude  Usage
# Dates
# 2019-01-13     Punjab      NR  31.519974  75.980003  135.8
# 2019-01-13    Haryana      NR  28.450006  77.019991  141.4
# 2019-01-13  Rajasthan      NR  26.449999  74.639981  186.9
# 2019-01-13      Delhi      NR  28.669993  77.230004   89.4
# 2019-01-13         UP      NR  27.599981  78.050006  310.0
# ...               ...     ...        ...        ...    ...
# 2019-01-12    Manipur     NER  24.799971  93.950017    2.6
# 2019-01-12  Meghalaya     NER  25.570492  91.880014    5.8
# 2019-01-12    Mizoram     NER  23.710399  92.720015    1.7
# 2019-01-12   Nagaland     NER  25.666998  94.116570    2.2
# 2019-01-12    Tripura     NER  23.835404  91.279999    5.8
# ...

# %%
############################### RESAMPLING ###################################

# %%
#Monthly Average of a Power Usage

# %%
df.Usage.resample('M').mean()
# Out:
# Dates
# 2019-01-31    104.701455
# 2019-02-28    104.794481
# 2019-03-31     98.533920
# 2019-04-30    106.853131
# 2019-05-31    103.320430
# 2019-06-30    104.985152
# 2019-07-31    100.835082
# 2019-08-31    100.872727
# 2019-09-30    101.980156
# 2019-10-31    101.824053
# 2019-11-30    100.596579
# 2019-12-31    103.200095
# 2020-01-31    106.640762
# 2020-02-29    106.333229
# 2020-03-31     98.842326
# 2020-04-30    104.755354
# 2020-05-31    102.562187
# Freq: M, Name: Usage, dtype: float64

# %%
df.Usage.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Dates'>

# %%
## Quartely Power Usage

# %%
df.Usage.resample('Q').mean()
# Out:
# Dates
# 2019-03-31    102.456349
# 2019-06-30    105.033866
# 2019-09-30    101.247463
# 2019-12-31    101.887018
# 2020-03-31    103.886147
# 2020-06-30    103.803602
# Freq: Q-DEC, Name: Usage, dtype: float64

# %%
df.Usage.resample('Q').mean().plot(kind="bar",color="red")
# Out:
# <AxesSubplot:xlabel='Dates'>

# %%
rng=pd.date_range(start="5-01-2019",end="5-02-2019",freq='S')
rng
# Out:
# DatetimeIndex(['2019-05-01 00:00:00', '2019-05-01 00:00:01',
#                '2019-05-01 00:00:02', '2019-05-01 00:00:03',
#                '2019-05-01 00:00:04', '2019-05-01 00:00:05',
#                '2019-05-01 00:00:06', '2019-05-01 00:00:07',
#                '2019-05-01 00:00:08', '2019-05-01 00:00:09',
#                ...
#                '2019-05-01 23:59:51', '2019-05-01 23:59:52',
#                '2019-05-01 23:59:53', '2019-05-01 23:59:54',
#                '2019-05-01 23:59:55', '2019-05-01 23:59:56',
#                '2019-05-01 23:59:57', '2019-05-01 23:59:58',
#                '2019-05-01 23:59:59', '2019-05-02 00:00:00'],
#               dtype='datetime64[ns]', length=86401, freq='S')

# %%
import pandas as pd

rng = pd.date_range(start='1/1/2019', end='1/3/2019', freq='H')
rng
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 01:00:00',
#                '2019-01-01 02:00:00', '2019-01-01 03:00:00',
#                '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 06:00:00', '2019-01-01 07:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 09:00:00',
#                '2019-01-01 10:00:00', '2019-01-01 11:00:00',
#                '2019-01-01 12:00:00', '2019-01-01 13:00:00',
#                '2019-01-01 14:00:00', '2019-01-01 15:00:00',
#                '2019-01-01 16:00:00', '2019-01-01 17:00:00',
#                '2019-01-01 18:00:00', '2019-01-01 19:00:00',
#                '2019-01-01 20:00:00', '2019-01-01 21:00:00',
#                '2019-01-01 22:00:00', '2019-01-01 23:00:00',
#                '2019-01-02 00:00:00', '2019-01-02 01:00:00',
#                '2019-01-02 02:00:00', '2019-01-02 03:00:00',
#                '2019-01-02 04:00:00', '2019-01-02 05:00:00',
# ...

# %%
df_selected = df[['States', 'Usage']]

usage_by_state = df_selected.groupby('States')['Usage'].sum()

plt.figure(figsize=(10, 8))
plt.pie(usage_by_state, labels=usage_by_state.index, autopct='%1.1f%%', startangle=140)
plt.title('Power Usage by State')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df' with the 'Dates' column as the index
# Convert the 'Dates' index to a datetime format if it's not already
df.index = pd.to_datetime(df.index)

# Extract the month and day of the week from the 'Dates' index
df['Month'] = df.index.month
df['Weekday'] = df.index.weekday

# Calculate total usage for weekdays and other days for each month
weekday_usage = df[df['Weekday'] < 5].groupby('Month')['Usage'].sum().fillna(0)
other_days_usage = df[df['Weekday'] >= 5].groupby('Month')['Usage'].sum().fillna(0)

# Plot the results for all months in a single bar plot
plt.figure(figsize=(10, 6))
plt.bar(months, weekday_usage, label='Weekdays', color='blue')
plt.bar(months, other_days_usage, label='Other Days', bottom=weekday_usage, color='orange')

plt.xlabel('Month')
plt.ylabel('Total Power Usage')
plt.title('Power Usage on Weekdays vs Other Days (Jan-Dec)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.index = pd.to_datetime(df.index)

# Extract the 'Usage' column
usage_data = df['Usage']

# Quantile plot analysis
quantiles = [0, 0.25, 0.5, 0.75, 1]
quantile_values = usage_data.quantile(quantiles)

# Plotting the quantile plot
plt.figure(figsize=(10, 6))
plt.plot(quantile_values.index, quantile_values.values, marker='o', linestyle='-', color='b')
plt.xlabel('Quantiles')
plt.ylabel('Usage')
plt.title('Quantile Plot Analysis for Usage')
plt.show()

# %%
df_selected = df[['Regions', 'Usage']]

usage_by_state = df_selected.groupby('Regions')['Usage'].sum()

plt.figure(figsize=(10, 8))
plt.pie(usage_by_state, labels=usage_by_state.index, autopct='%1.1f%%', startangle=140)
plt.title('Power Usage by Regions')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df' with the 'Dates' column as the index
# Convert the 'Dates' index to a datetime format if it's not already
df.index = pd.to_datetime(df.index)

df['Weekday'] = df.index.weekday

# Filter data for weekdays (Monday to Friday)
weekday_data = df[df['Weekday'] < 5]

# Group by 'Regions' and calculate the total power usage for each region on weekdays
weekday_usage_by_region = weekday_data.groupby('Regions')['Usage'].sum()

# Plotting the stacked bar chart
plt.figure(figsize=(10, 6))
weekday_usage_by_region.plot(kind='bar', stacked=True, color='purple')
plt.xlabel('Regions')
plt.ylabel('Total Power Usage on Weekdays')
plt.title('Total Power Usage by Region on Weekdays')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df' with the 'Dates' column as the index
# Convert the 'Dates' index to a datetime format if it's not already
df.index = pd.to_datetime(df.index)

# Define a function to categorize dates into seasons
def get_season(month):
    if 6 <= month <= 9:
        return 'Monsoon'
    elif 3 <= month <= 5:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Post Monsoon'
    else:
        return 'Winter'

# Apply the function to create a new column 'Season'
df['Season'] = df.index.month.map(get_season)

# Group by 'Season' and calculate the total power usage for each season
seasonal_usage = df.groupby('Season')['Usage'].sum()

# Plotting the bar chart for seasonal power usage
plt.figure(figsize=(8, 6))
seasonal_usage.plot(kind='bar', color='green')
plt.xlabel('Season')
plt.ylabel('Total Power Usage')
plt.title('Total Power Usage by Season')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Convert the 'Dates' index to a datetime format if it's not already
df.index = pd.to_datetime(df.index)

# Select relevant columns for correlation analysis
numerical_columns = ['latitude', 'longitude', 'Usage']

# Calculate the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df' with the 'Dates' column as the index
df.index = pd.to_datetime(df.index)

# Insight 1: Seasonal Patterns
df['Month'] = df.index.month
seasonal_usage = df.groupby('Month')['Usage'].mean()

# Plotting Seasonal Patterns
plt.figure(figsize=(10, 6))
sns.lineplot(x=seasonal_usage.index, y=seasonal_usage.values)
plt.title('Seasonal Patterns in Power Consumption')
plt.xlabel('Month')
plt.ylabel('Average Power Usage')
plt.show()

# %%
sns.boxplot(x=df['Usage'],color="green")
plt.title('Boxplot for Power Consumption')
plt.show()

# %%
monthly_variability = df.groupby(df.index.month)['Usage'].max() - df.groupby(df.index.month)['Usage'].min()

# Plotting Monthly Variability
plt.figure(figsize=(10, 6))
monthly_variability.plot(kind='bar',color="red")
plt.title('Monthly Variability in Power Consumption')
plt.xlabel('Month')
plt.ylabel('Power Usage Variability')
plt.show()

# %%
monthly_trend = df.resample('M')['Usage'].mean()

# Plotting Trends Over Time
plt.figure(figsize=(10, 6))
monthly_trend.plot(marker='o')
plt.title('Trends Over Time in Power Consumption')
plt.xlabel('Date')
plt.ylabel('Average Power Usage')
plt.show()

# %% [markdown]
# INSIGHTS Found:
#
# 1.Power Consumed more in India at Weekdays when compared to other Days
#
# 2.West region consumes more power when compared to other regions.
#
# 3.Maharastra is the largest power consumer in India
#
# 4.In Summer season,the power consumed is more
